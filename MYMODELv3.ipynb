# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import keras
import pandas as pd
from keras.models import Sequential, Model, load_model
from keras.layers import Input, MaxPooling2D,Conv2D,Dense, Dropout, Activation,Flatten, BatchNormalization
from keras.optimizers import Adam,sgd
from sklearn.metrics import roc_auc_score
from keras.callbacks import Callback, EarlyStopping
from keras.models import model_from_json
import h5py
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
os.listdir()
os.chdir('gdrive/My Drive/MyMIR')
os.listdir()
os.chdir('final_Xtrain')

# %%
os.chdir('../final_Xtrain')

# %%
Xtrain = []
Ytrain = []
Xtest = []
Ytest = []
Xval = []
Yval = []

# %%
#Xtrain = np.load("data1.npy")
#Xtest = np.load("dataB.npy")
Xval = np.load("dataC.npy")
os.chdir('../final_Ytrain')
#Ytrain = np.load("Y1.npy")
#Ytest = np.load("YB.npy")
Yval = np.load("YC.npy")

# %%
#Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],Xtrain.shape[2],1)
#print(Xtrain.shape)
#Xtest = Xtest.reshape(Xtest.shape[0],Xtest.shape[1],Xtest.shape[2],1)
#print(Xtest.shape)
Xval = Xval.reshape(Xval.shape[0],Xval.shape[1],Xval.shape[2],1)
print(Xval.shape)
# Out:
# (1825, 128, 1255, 1)

# %%
def auc_roc(y_true, y_pred):
    # any tensorflow metric
    value, update_op = tf.contrib.metrics.streaming_auc(y_pred, y_true)

    # find all variables created for this metric
    metric_vars = [i for i in tf.local_variables() if 'auc_roc' in i.name.split('/')[1]]

    # Add metric variables to GLOBAL_VARIABLES collection.
    # They will be initialized for new session.
    for v in metric_vars:
        tf.add_to_collection(tf.GraphKeys.GLOBAL_VARIABLES, v)

    # force to update metric values
    with tf.control_dependencies([update_op]):
        value = tf.identity(value)
        return value

# %%
my_callbacks = [EarlyStopping(monitor='auc_roc', patience=300, verbose=1, mode='max')]

# %%
model = Sequential()
model.add(Conv2D(32,(5,5),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32,(5,5),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(5,5),activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten()) 
model.add(Dense(120,activation = 'relu'))
model.add(Dense(84,activation = 'relu'))
model.add(Dense(50,activation = 'sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',auc_roc])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5f15418b3570> in <module>()
# ----> 1 model.summary()
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py in summary(self, line_length, positions, print_fn)
#    1250         if not self.built:
#    1251             raise ValueError(
# -> 1252                 'This model has not yet been built. '
#    1253                 'Build the model first by calling build() '
#    1254                 'or calling fit() with some data. '
#
# ValueError: This model has not yet been built. Build the model first by calling build() or calling fit() with some data. Or specify input_shape or batch_input_shape in the first layer for automatic build.

# %%
os.listdir()
os.chdir('../final_Xtrain')

# %%
for i in range(0,14):
  if i<10:
    Xtrain = np.load('data'+str(i)+'.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('Y'+str(i)+'.npy')
    os.chdir('../final_Xtrain')
  elif i == 10:
    Xtrain = np.load('dataA.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YA.npy')
    os.chdir('../final_Xtrain')
  elif i == 11:
    Xtrain = np.load('dataB.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YB.npy')
    os.chdir('../final_Xtrain')
  elif i == 12:
    Xtrain = np.load('dataD.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YD.npy')
    os.chdir('../final_Xtrain')
  else:
    Xtrain = np.load('dataE.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YE.npy')
    os.chdir('../final_Xtrain')
  Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],Xtrain.shape[2],1)
  Xval = Xval.reshape(Xval.shape[0],Xval.shape[1],Xval.shape[2],1)
  model.fit(Xtrain, Ytrain,batch_size=64,epochs=10,verbose=1,validation_data = (Xval,Yval),shuffle=True)
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-7-2900e3a86cfc>:3: streaming_auc (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.auc. Note that the order of the labels and predictions arguments has been switched.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:526: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1108 samples, validate on 1825 samples
# Epoch 1/10
# 1108/1108 [==============================] - 25s 22ms/step - loss: 0.9446 - acc: 0.8110 - auc_roc: 0.4781 - val_loss: 0.3701 - val_acc: 0.9415 - val_auc_roc: 0.5240
# Epoch 2/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.3420 - acc: 0.9438 - auc_roc: 0.5337 - val_loss: 0.3040 - val_acc: 0.9440 - val_auc_roc: 0.5487
# Epoch 3/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.2193 - acc: 0.9476 - auc_roc: 0.5634 - val_loss: 0.2499 - val_acc: 0.9436 - val_auc_roc: 0.5807
# Epoch 4/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1708 - acc: 0.9496 - auc_roc: 0.5975 - val_loss: 0.2391 - val_acc: 0.9433 - val_auc_roc: 0.6124
# Epoch 5/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1475 - acc: 0.9537 - auc_roc: 0.6259 - val_loss: 0.2509 - val_acc: 0.9418 - val_auc_roc: 0.6377
# Epoch 6/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1273 - acc: 0.9587 - auc_roc: 0.6486 - val_loss: 0.2889 - val_acc: 0.9406 - val_auc_roc: 0.6575
# Epoch 7/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1158 - acc: 0.9626 - auc_roc: 0.6644 - val_loss: 0.3091 - val_acc: 0.9389 - val_auc_roc: 0.6718
# Epoch 8/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1083 - acc: 0.9654 - auc_roc: 0.6773 - val_loss: 0.3356 - val_acc: 0.9392 - val_auc_roc: 0.6828
# Epoch 9/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.1003 - acc: 0.9679 - auc_roc: 0.6865 - val_loss: 0.3509 - val_acc: 0.9374 - val_auc_roc: 0.6909
# Epoch 10/10
# 1108/1108 [==============================] - 15s 14ms/step - loss: 0.0903 - acc: 0.9720 - auc_roc: 0.6940 - val_loss: 0.4212 - val_acc: 0.9376 - val_auc_roc: 0.6964
# Train on 1543 samples, validate on 1825 samples
# Epoch 1/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.2448 - acc: 0.9447 - auc_roc: 0.6901 - val_loss: 0.2123 - val_acc: 0.9440 - val_auc_roc: 0.6897
# Epoch 2/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1835 - acc: 0.9483 - auc_roc: 0.6902 - val_loss: 0.2062 - val_acc: 0.9434 - val_auc_roc: 0.6912
# Epoch 3/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1736 - acc: 0.9492 - auc_roc: 0.6925 - val_loss: 0.2091 - val_acc: 0.9433 - val_auc_roc: 0.6937
# Epoch 4/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1605 - acc: 0.9514 - auc_roc: 0.6957 - val_loss: 0.2189 - val_acc: 0.9429 - val_auc_roc: 0.6972
# Epoch 5/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1445 - acc: 0.9547 - auc_roc: 0.6995 - val_loss: 0.2408 - val_acc: 0.9402 - val_auc_roc: 0.7014
# Epoch 6/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1296 - acc: 0.9585 - auc_roc: 0.7037 - val_loss: 0.2928 - val_acc: 0.9361 - val_auc_roc: 0.7054
# Epoch 7/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1159 - acc: 0.9628 - auc_roc: 0.7072 - val_loss: 0.3172 - val_acc: 0.9332 - val_auc_roc: 0.7091
# Epoch 8/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.1039 - acc: 0.9671 - auc_roc: 0.7109 - val_loss: 0.3557 - val_acc: 0.9311 - val_auc_roc: 0.7128
# Epoch 9/10
# 1543/1543 [==============================] - 19s 12ms/step - loss: 0.0962 - acc: 0.9695 - auc_roc: 0.7143 - val_loss: 0.3942 - val_acc: 0.9323 - val_auc_roc: 0.7158
# Epoch 10/10
# 1536/1543 [============================>.] - ETA: 0s - loss: 0.0856 - acc: 0.9736 - auc_roc: 0.7168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-deb76913811d> in <module>()
#      27   Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],Xtrain.shape[2],1)
#      28   Xval = Xval.reshape(Xval.shape[0],Xval.shape[1],Xval.shape[2],1)
# ---> 29   model.fit(Xtrain, Ytrain,batch_size=64,epochs=10,verbose=1,validation_data = (Xval,Yval),shuffle=True)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     210                         val_outs = test_loop(model, val_f, val_ins,
#     211                                              batch_size=batch_size,
# --> 212                                              verbose=0)
#     213                         val_outs = to_list(val_outs)
#     214                         # Same labels assumed.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in test_loop(model, f, ins, batch_size, verbose, steps)
#     386                 ins_batch = slice_arrays(ins[:-1], batch_ids) + [ins[-1]]
#     387             else:
# --> 388                 ins_batch = slice_arrays(ins, batch_ids)
#     389             for i in indices_for_conversion_to_dense:
#     390                 ins_batch[i] = ins_batch[i].toarray()
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/generic_utils.py in slice_arrays(arrays, start, stop)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/generic_utils.py in <listcomp>(.0)
#     524             if hasattr(start, 'shape'):
#     525                 start = start.tolist()
# --> 526             return [None if x is None else x[start] for x in arrays]
#     527         else:
#     528             return [None if x is None else x[start:stop] for x in arrays]
#
# KeyboardInterrupt:

# %%
tempx = [['dataD.npy','YD.npy'],['dataE.npy','YE.npy'],['dataF.npy','YF.npy']]
for tple in tempx:
  Xtestp,Ytestp = tple
  os.chdir('../final_Xtrain')
  Xtest = np.load(Xtestp)
  os.chdir('../final_Ytrain')
  Ytest = np.load(Ytestp)
  Xtest = Xtest.reshape(Xtest.shape[0],Xtest.shape[1],Xtest.shape[2],1)
  predicted = model.predict(Xtest,batch_size=32)
  print(roc_auc_score(Ytest, predicted))
# Out:
# 0.5640806313544607
# 0.580587643826309
# 0.5840373395196568

# %%
os.chdir('/content/gdrive/My Drive/MyMIR/model')

# %%
os.chdir('/content/gdrive/My Drive/MyMIR/final_Ytrain')

# %%
# load json and create model
json_file = open('modelv6.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("modelv6.h5")
print("Loaded model from disk")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Loaded model from disk

# %%
loaded_model.summary()
loaded_model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',auc_roc])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 124, 1251, 64)     1664
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 625, 64)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 58, 621, 64)       102464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 310, 64)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 306, 128)      204928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 153, 128)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 149, 256)       819456
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 74, 256)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 75776)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               15155400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 200)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               24120
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                6050
# =================================================================
# Total params: 16,314,082
# Trainable params: 16,314,082
# Non-trainable params: 0
# _________________________________________________________________
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-6-2900e3a86cfc>:3: streaming_auc (from tensorflow.contrib.metrics.python.ops.metric_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.metrics.auc. Note that the order of the labels and predictions arguments has been switched.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:526: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:788: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.

# %%
os.listdir()
os.chdir('../final_Xtrain')
for i in range(12,14):
  if i == 12:
    Xtrain = np.load('dataD.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YD.npy')
    os.chdir('../final_Xtrain')
  else:
    Xtrain = np.load('dataE.npy')
    os.chdir('../final_Ytrain')
    Ytrain = np.load('YE.npy')
    os.chdir('../final_Xtrain')
  Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1],Xtrain.shape[2],1)
  Xval = Xval.reshape(Xval.shape[0],Xval.shape[1],Xval.shape[2],1)
  loaded_model.fit(Xtrain, Ytrain,batch_size=32,epochs=10,verbose=1,validation_data = (Xval,Yval),shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1677 samples, validate on 1825 samples
# Epoch 1/10
# 1677/1677 [==============================] - 52s 31ms/step - loss: 0.1852 - acc: 0.9483 - auc_roc: 0.7262 - val_loss: 0.1851 - val_acc: 0.9442 - val_auc_roc: 0.7596
# Epoch 2/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1773 - acc: 0.9489 - auc_roc: 0.7683 - val_loss: 0.1810 - val_acc: 0.9444 - val_auc_roc: 0.7733
# Epoch 3/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1760 - acc: 0.9490 - auc_roc: 0.7778 - val_loss: 0.1814 - val_acc: 0.9444 - val_auc_roc: 0.7796
# Epoch 4/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1738 - acc: 0.9490 - auc_roc: 0.7819 - val_loss: 0.1818 - val_acc: 0.9443 - val_auc_roc: 0.7833
# Epoch 5/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1723 - acc: 0.9490 - auc_roc: 0.7851 - val_loss: 0.1832 - val_acc: 0.9444 - val_auc_roc: 0.7859
# Epoch 6/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1696 - acc: 0.9492 - auc_roc: 0.7870 - val_loss: 0.1818 - val_acc: 0.9442 - val_auc_roc: 0.7881
# Epoch 7/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1674 - acc: 0.9494 - auc_roc: 0.7893 - val_loss: 0.1829 - val_acc: 0.9443 - val_auc_roc: 0.7901
# Epoch 8/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1654 - acc: 0.9492 - auc_roc: 0.7912 - val_loss: 0.1825 - val_acc: 0.9439 - val_auc_roc: 0.7922
# Epoch 9/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1631 - acc: 0.9496 - auc_roc: 0.7934 - val_loss: 0.1803 - val_acc: 0.9440 - val_auc_roc: 0.7946
# Epoch 10/10
# 1677/1677 [==============================] - 42s 25ms/step - loss: 0.1594 - acc: 0.9503 - auc_roc: 0.7960 - val_loss: 0.1841 - val_acc: 0.9438 - val_auc_roc: 0.7967
# Train on 1547 samples, validate on 1825 samples
# Epoch 1/10
# 1547/1547 [==============================] - 42s 27ms/step - loss: 0.1690 - acc: 0.9482 - auc_roc: 0.7968 - val_loss: 0.1722 - val_acc: 0.9445 - val_auc_roc: 0.7983
# Epoch 2/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1592 - acc: 0.9488 - auc_roc: 0.8004 - val_loss: 0.1719 - val_acc: 0.9439 - val_auc_roc: 0.8022
# Epoch 3/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1537 - acc: 0.9494 - auc_roc: 0.8043 - val_loss: 0.1742 - val_acc: 0.9419 - val_auc_roc: 0.8061
# Epoch 4/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1505 - acc: 0.9499 - auc_roc: 0.8079 - val_loss: 0.1742 - val_acc: 0.9425 - val_auc_roc: 0.8097
# Epoch 5/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1485 - acc: 0.9504 - auc_roc: 0.8114 - val_loss: 0.1729 - val_acc: 0.9425 - val_auc_roc: 0.8130
# Epoch 6/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1450 - acc: 0.9508 - auc_roc: 0.8148 - val_loss: 0.1713 - val_acc: 0.9423 - val_auc_roc: 0.8164
# Epoch 7/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1426 - acc: 0.9510 - auc_roc: 0.8180 - val_loss: 0.1744 - val_acc: 0.9410 - val_auc_roc: 0.8195
# Epoch 8/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1420 - acc: 0.9514 - auc_roc: 0.8208 - val_loss: 0.1696 - val_acc: 0.9421 - val_auc_roc: 0.8223
# Epoch 9/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1379 - acc: 0.9522 - auc_roc: 0.8238 - val_loss: 0.1682 - val_acc: 0.9426 - val_auc_roc: 0.8253
# Epoch 10/10
# 1547/1547 [==============================] - 40s 26ms/step - loss: 0.1366 - acc: 0.9523 - auc_roc: 0.8267 - val_loss: 0.1728 - val_acc: 0.9421 - val_auc_roc: 0.8279

# %%
#loaded_model.compile(loss='binary_crossentropy' , optimizer='adam' , metrics=['accuracy',auc_roc])
os.chdir('/content/gdrive/My Drive/MyMIR/final_Xtrain')
temp_x = np.load("dataF.npy")
temp_x = temp_x.reshape(temp_x.shape[0],temp_x.shape[1],temp_x.shape[2],1)
os.chdir('/content/gdrive/My Drive/MyMIR/final_Ytrain')
temp_y = np.load("YF.npy")
loss,accuracy,auc_score= loaded_model.evaluate(temp_x,temp_y,batch_size=32)
print(loss,accuracy,auc_score)
# Out:
# 2105/2105 [==============================] - 15s 7ms/step
# 0.17003020439606664 0.9430593867483161 0.8359284104474084

# %%
model_json = loaded_model.to_json()
with open("modelv6.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
loaded_model.save_weights("modelv6.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
#os.chdir('/content/gdrive/My Drive/MyMIR')
os.listdir()
#model.save('/content/gdrive/My Drive/MyMIR/model/modelv1.h5')
# Out:
# ['YF.npy',
#  'YE.npy',
#  'YD.npy',
#  'YC.npy',
#  'YB.npy',
#  'YA.npy',
#  'Y9.npy',
#  'Y8.npy',
#  'Y7.npy',
#  'Y6.npy',
#  'Y5.npy',
#  'Y4.npy',
#  'Y3.npy',
#  'Y2.npy',
#  'Y1.npy',
#  'Y0.npy',
#  'modelv6.json',
#  'modelv6.h5']
