# %%
import pandas as pd
import numpy as np
import os
import shutil
import librosa
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
list_data = []
savename = "file-duration29.npy"

# %%
start = time.time()

counter = 0

for index, row in clip_address.iterrows() :
  path = '/content/' + row['mp3_path']
  wavedata, samplerate = librosa.load(path, sr=2108)
  wavedata = wavedata[np.newaxis, :]
  list_data.append(wavedata)
  
  if counter%250 == 0:
    print(counter)
  counter = counter + 1
  
np.save("list_data-" + savename, list_data)
print(time.time() - start)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-34056718ce4f> in <module>()
#       3 counter = 0
#       4
# ----> 5 for index, row in clip_address.iterrows() :
#       6   path = '/content/' + row['mp3_path']
#       7   wavedata, samplerate = librosa.load(path, sr=2108)
#
# NameError: name 'clip_address' is not defined
